# %%
import import_ipynb
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
from model import build_unet
from metrics import dice_loss, dice_coef, iou

# Rest of the code...




def create_dir(path):
    """ Create a directory if it doesn't exist. """
    os.makedirs(path, exist_ok=True)


def load_data(path, split=0.1):
    images = sorted(glob(os.path.join(path, "CXR_png", "*.png")))
    masks1 = sorted(glob(os.path.join(path, "GTMask", "leftMask", "*.png")))
    masks2 = sorted(glob(os.path.join(path, "GTMask", "rightMask", "*.png")))

    train_x, valid_x, train_y1, valid_y1, train_y2, valid_y2 = train_test_split(
        images, masks1, masks2, test_size=split, random_state=42
    )

    train_x, test_x, train_y1, test_y1, train_y2, test_y2 = train_test_split(
        train_x, train_y1, train_y2, test_size=split, random_state=42
    )

    return (train_x, train_y1, train_y2), (valid_x, valid_y1, valid_y2), (test_x, test_y1, test_y2)


def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x.astype(np.float32) / 255.0
    return x


def read_mask(path1, path2):
    x1 = cv2.imread(path1, cv2.IMREAD_GRAYSCALE)
    x2 = cv2.imread(path2, cv2.IMREAD_GRAYSCALE)
    x = x1 + x2
    x = cv2.resize(x, (W, H))
    x = x.astype(np.float32) / np.max(x)
    x = x > 0.5
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x


def tf_parse(x, y1, y2):
    def _parse(x, y1, y2):
        x = x.decode()
        y1 = y1.decode()
        y2 = y2.decode()

        x = read_image(x)
        y = read_mask(y1, y2)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y1, y2], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y


def tf_dataset(X, Y1, Y2, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y1, Y2))
    dataset = dataset.shuffle(buffer_size=200)
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files3")

    """ Global parameters """
    H = 512
    W = 512

    """ Hyperparameters """
    batch_size = 2
    lr = 1e-5
    num_epochs = 30
    model_path = os.path.join("files3", "model")
    csv_path = os.path.join("files3", "data.csv")

    """ Dataset """
    dataset_path = "C:\\Users\\IIITSKLM\\Desktop\\indiana"

    (train_x, train_y1, train_y2), (valid_x, valid_y1, valid_y2), (test_x, test_y1, test_y2) = load_data(dataset_path)
    print(f"Train: {len(train_x)} - {len(train_y1)} - {len(train_y2)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y1)} - {len(valid_y2)}")
    print(f"Test: {len(test_x)} - {len(test_y1)} - {len(test_y2)}")

    train_dataset = tf_dataset(train_x, train_y1, train_y2, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y1, valid_y2, batch=batch_size)

    """ Model """
    model = build_unet((H, W, 3))
    metrics = [dice_coef, iou, Recall(), Precision()]
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=metrics)

    callbacks = [
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path)
    ]

    print("Training started...")
    model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
    print("Training completed.")

    """ Save the model """
    model.save(model_path, save_format='tf')

    """ Inspect the data """
    sample_idx = 0  # Index of the sample to visualize
    sample_image = read_image(train_x[sample_idx])
    sample_mask = read_mask(train_y1[sample_idx], train_y2[sample_idx])

    # Print the shapes of the sample image and mask
    print("Sample Image Shape:", sample_image.shape)
    print("Sample Mask Shape:", sample_mask.shape)

    # Visualize the sample image and mask
    cv2.imshow("Sample Image", sample_image)
    cv2.imshow("Sample Mask", sample_mask)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# importing Jupyter notebook from model.ipynb
# 2.13.0
# importing Jupyter notebook from metrics.ipynb
# Train: 44 - 44 - 44
# Valid: 6 - 6 - 6
# Test: 5 - 5 - 5
# Training started...
# Epoch 1/30
# 22/22 [==============================] - 682s 31s/step - loss: 0.6276 - dice_coef: 0.3724 - iou: 0.2296 - recall: 0.4177 - precision: 0.4287 - val_loss: 0.6979 - val_dice_coef: 0.3021 - val_iou: 0.1782 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-05
# Epoch 2/30
# 22/22 [==============================] - 673s 31s/step - loss: 0.5116 - dice_coef: 0.4884 - iou: 0.3240 - recall: 0.6978 - precision: 0.5477 - val_loss: 0.7045 - val_dice_coef: 0.2955 - val_iou: 0.1735 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-05
# Epoch 3/30
# 22/22 [==============================] - 665s 30s/step - loss: 0.4281 - dice_coef: 0.5719 - iou: 0.4017 - recall: 0.7895 - precision: 0.6058 - val_loss: 0.7119 - val_dice_coef: 0.2881 - val_iou: 0.1685 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-05
# Epoch 4/30
# 22/22 [==============================] - 673s 31s/step - loss: 0.3384 - dice_coef: 0.6616 - iou: 0.4956 - recall: 0.8782 - precision: 0.7378 - val_loss: 0.7227 - val_dice_coef: 0.2773 - val_iou: 0.1611 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-05
# Epoch 5/30
# 22/22 [==============================] - 664s 30s/step - loss: 0.2590 - dice_coef: 0.7410 - iou: 0.5897 - recall: 0.9299 - precision: 0.8658 - val_loss: 0.7364 - val_dice_coef: 0.2636 - val_iou: 0.1519 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-05
# Epoch 6/30
# 22/22 [==============================] - ETA: 0s - loss: 0.2107 - dice_coef: 0.7893 - iou: 0.6529 - recall: 0.9477 - precision: 0.8995
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 22/22 [==============================] - 669s 30s/step - loss: 0.2107 - dice_coef: 0.7893 - iou: 0.6529 - recall: 0.9477 - precision: 0.8995 - val_loss: 0.7522 - val_dice_coef: 0.2478 - val_iou: 0.1415 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-05
# Epoch 7/30
# 22/22 [==============================] - 667s 30s/step - loss: 0.1920 - dice_coef: 0.8080 - iou: 0.6791 - recall: 0.9524 - precision: 0.9189 - val_loss: 0.7678 - val_dice_coef: 0.2322 - val_iou: 0.1315 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-06
# Epoch 8/30
# 22/22 [==============================] - 700s 32s/step - loss: 0.1887 - dice_coef: 0.8113 - iou: 0.6834 - recall: 0.9522 - precision: 0.9190 - val_loss: 0.7807 - val_dice_coef: 0.2193 - val_iou: 0.1232 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-06
# Epoch 9/30
# 22/22 [==============================] - 668s 30s/step - loss: 0.1859 - dice_coef: 0.8141 - iou: 0.6875 - recall: 0.9546 - precision: 0.9174 - val_loss: 0.7929 - val_dice_coef: 0.2071 - val_iou: 0.1155 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-06
# Epoch 10/30
# 22/22 [==============================] - 670s 31s/step - loss: 0.1817 - dice_coef: 0.8183 - iou: 0.6935 - recall: 0.9571 - precision: 0.9224 - val_loss: 0.8025 - val_dice_coef: 0.1975 - val_iou: 0.1096 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-06
# Epoch 11/30
# 22/22 [==============================] - ETA: 0s - loss: 0.1822 - dice_coef: 0.8178 - iou: 0.6930 - recall: 0.9538 - precision: 0.9222
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1e-07.
# 22/22 [==============================] - 675s 31s/step - loss: 0.1822 - dice_coef: 0.8178 - iou: 0.6930 - recall: 0.9538 - precision: 0.9222 - val_loss: 0.8099 - val_dice_coef: 0.1901 - val_iou: 0.1050 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-06
# Epoch 12/30
# 22/22 [==============================] - 671s 31s/step - loss: 0.1794 - dice_coef: 0.8206 - iou: 0.6965 - recall: 0.9560 - precision: 0.9262 - val_loss: 0.8153 - val_dice_coef: 0.1847 - val_iou: 0.1018 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-07
# Epoch 13/30
# 22/22 [==============================] - 674s 31s/step - loss: 0.1791 - dice_coef: 0.8209 - iou: 0.6969 - recall: 0.9548 - precision: 0.9259 - val_loss: 0.8191 - val_dice_coef: 0.1809 - val_iou: 0.0995 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-07
# Epoch 14/30
# 22/22 [==============================] - 670s 31s/step - loss: 0.1782 - dice_coef: 0.8218 - iou: 0.6987 - recall: 0.9573 - precision: 0.9219 - val_loss: 0.8204 - val_dice_coef: 0.1796 - val_iou: 0.0987 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-07
# Epoch 15/30
# 22/22 [==============================] - 680s 31s/step - loss: 0.1806 - dice_coef: 0.8194 - iou: 0.6951 - recall: 0.9541 - precision: 0.9229 - val_loss: 0.8212 - val_dice_coef: 0.1788 - val_iou: 0.0982 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-07
# Epoch 16/30
# 22/22 [==============================] - 698s 32s/step - loss: 0.1807 - dice_coef: 0.8193 - iou: 0.6954 - recall: 0.9555 - precision: 0.9234 - val_loss: 0.8213 - val_dice_coef: 0.1787 - val_iou: 0.0981 - val_recall: 8.6675e-06 - val_precision: 0.0030 - lr: 1.0000e-07
# Epoch 17/30
# 22/22 [==============================] - 680s 31s/step - loss: 0.1775 - dice_coef: 0.8225 - iou: 0.6995 - recall: 0.9567 - precision: 0.9264 - val_loss: 0.8122 - val_dice_coef: 0.1878 - val_iou: 0.1036 - val_recall: 0.0053 - val_precision: 0.5331 - lr: 1.0000e-07
# Epoch 18/30
# 22/22 [==============================] - 667s 30s/step - loss: 0.1799 - dice_coef: 0.8201 - iou: 0.6963 - recall: 0.9536 - precision: 0.9240 - val_loss: 0.7793 - val_dice_coef: 0.2207 - val_iou: 0.1247 - val_recall: 0.0423 - val_precision: 0.8142 - lr: 1.0000e-07
# Epoch 19/30
# 22/22 [==============================] - 673s 31s/step - loss: 0.1791 - dice_coef: 0.8209 - iou: 0.6973 - recall: 0.9549 - precision: 0.9244 - val_loss: 0.7217 - val_dice_coef: 0.2783 - val_iou: 0.1626 - val_recall: 0.1141 - val_precision: 0.8775 - lr: 1.0000e-07
# Epoch 20/30
# 22/22 [==============================] - 670s 31s/step - loss: 0.1772 - dice_coef: 0.8228 - iou: 0.6998 - recall: 0.9552 - precision: 0.9253 - val_loss: 0.6556 - val_dice_coef: 0.3444 - val_iou: 0.2093 - val_recall: 0.1992 - val_precision: 0.8896 - lr: 1.0000e-07
# Epoch 21/30
# 22/22 [==============================] - 671s 31s/step - loss: 0.1752 - dice_coef: 0.8248 - iou: 0.7029 - recall: 0.9585 - precision: 0.9270 - val_loss: 0.5811 - val_dice_coef: 0.4189 - val_iou: 0.2715 - val_recall: 0.3094 - val_precision: 0.9018 - lr: 1.0000e-07
# Epoch 22/30
# 22/22 [==============================] - 674s 31s/step - loss: 0.1759 - dice_coef: 0.8241 - iou: 0.7017 - recall: 0.9575 - precision: 0.9252 - val_loss: 0.4970 - val_dice_coef: 0.5030 - val_iou: 0.3398 - val_recall: 0.4452 - val_precision: 0.9104 - lr: 1.0000e-07
# Epoch 23/30
# 22/22 [==============================] - 711s 32s/step - loss: 0.1758 - dice_coef: 0.8242 - iou: 0.7017 - recall: 0.9556 - precision: 0.9270 - val_loss: 0.4278 - val_dice_coef: 0.5722 - val_iou: 0.4023 - val_recall: 0.5638 - val_precision: 0.9149 - lr: 1.0000e-07
# Epoch 24/30
# 22/22 [==============================] - 671s 31s/step - loss: 0.1756 - dice_coef: 0.8244 - iou: 0.7024 - recall: 0.9571 - precision: 0.9266 - val_loss: 0.3683 - val_dice_coef: 0.6317 - val_iou: 0.4626 - val_recall: 0.6700 - val_precision: 0.9164 - lr: 1.0000e-07
# Epoch 25/30
# 22/22 [==============================] - 668s 30s/step - loss: 0.1751 - dice_coef: 0.8249 - iou: 0.7028 - recall: 0.9580 - precision: 0.9277 - val_loss: 0.3243 - val_dice_coef: 0.6757 - val_iou: 0.5113 - val_recall: 0.7677 - val_precision: 0.9184 - lr: 1.0000e-07
# Epoch 26/30
# 22/22 [==============================] - 667s 30s/step - loss: 0.1773 - dice_coef: 0.8227 - iou: 0.6996 - recall: 0.9542 - precision: 0.9287 - val_loss: 0.2926 - val_dice_coef: 0.7074 - val_iou: 0.5479 - val_recall: 0.8231 - val_precision: 0.9170 - lr: 1.0000e-07
# Epoch 27/30
# 22/22 [==============================] - 674s 31s/step - loss: 0.1757 - dice_coef: 0.8243 - iou: 0.7021 - recall: 0.9568 - precision: 0.9283 - val_loss: 0.2759 - val_dice_coef: 0.7241 - val_iou: 0.5684 - val_recall: 0.8489 - val_precision: 0.9134 - lr: 1.0000e-07
# Epoch 28/30
# 22/22 [==============================] - 660s 30s/step - loss: 0.1749 - dice_coef: 0.8251 - iou: 0.7032 - recall: 0.9584 - precision: 0.9251 - val_loss: 0.2651 - val_dice_coef: 0.7349 - val_iou: 0.5818 - val_recall: 0.8630 - val_precision: 0.9133 - lr: 1.0000e-07
# Epoch 29/30
# 22/22 [==============================] - 667s 30s/step - loss: 0.1751 - dice_coef: 0.8249 - iou: 0.7030 - recall: 0.9567 - precision: 0.9265 - val_loss: 0.2547 - val_dice_coef: 0.7453 - val_iou: 0.5941 - val_recall: 0.8722 - val_precision: 0.9150 - lr: 1.0000e-07
# Epoch 30/30
# 22/22 [==============================] - 677s 31s/step - loss: 0.1742 - dice_coef: 0.8258 - iou: 0.7040 - recall: 0.9563 - precision: 0.9283 - val_loss: 0.2479 - val_dice_coef: 0.7521 - val_iou: 0.6028 - val_recall: 0.8784 - val_precision: 0.9176 - lr: 1.0000e-07
# Training completed.
# INFO:tensorflow:Assets written to: files3\model\assets
# INFO:tensorflow:Assets written to: files3\model\assets
# Sample Image Shape: (512, 512, 3)
# Sample Mask Shape: (512, 512, 1)
